# %%
import pandas as pd

# %%
df = pd.read_csv('covid-data.csv')
df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 86452      ZWE    Africa     Zimbabwe  2021-05-02      38281.0       21.0
# 86453      ZWE    Africa     Zimbabwe  2021-05-03      38293.0       12.0
# 86454      ZWE    Africa     Zimbabwe  2021-05-04      38327.0       34.0
# 86455      ZWE    Africa     Zimbabwe  2021-05-05      38357.0       30.0
# 86456      ZWE    Africa     Zimbabwe  2021-05-06      38398.0       41.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
new_df = df[['location','date','new_cases']]
new_df = new_df.set_index('date')
new_df
# Out:
#                location  new_cases
# date
# 2020-02-24  Afghanistan        1.0
# 2020-02-25  Afghanistan        0.0
# 2020-02-26  Afghanistan        0.0
# 2020-02-27  Afghanistan        0.0
# 2020-02-28  Afghanistan        0.0
# ...                 ...        ...
# 2021-05-02     Zimbabwe       21.0
# 2021-05-03     Zimbabwe       12.0
# 2021-05-04     Zimbabwe       34.0
# 2021-05-05     Zimbabwe       30.0
# 2021-05-06     Zimbabwe       41.0
#
# [86457 rows x 2 columns]

# %%
y_values = list(country_df.index.values)[::40]

import matplotlib.pyplot as plt

country_dict = {}
countries_to_plot = ['Poland', 'Germany']

for country in countries_to_plot:
    country_df=new_df[new_df['location'] == country]
    x_values = [country_df.at[index, 'new_cases'] for index in y_values]
    country_dict[country] = x_values

df=pd.DataFrame(country_dict, index=y_values)

df.plot(kind="barh", title="Covid 19 daily new cases",
        color={"green", "red"})

plt.xlabel('New cases')
plt.grid(True)
plt.legend()
plt.tight_layout()
